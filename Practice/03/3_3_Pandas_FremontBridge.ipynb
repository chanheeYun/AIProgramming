# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../../DataScienceHandbook/data/FremontBridge.csv', index_col='Date', parse_dates=True)
data.info()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13232\2566049832.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data = pd.read_csv('../../DataScienceHandbook/data/FremontBridge.csv', index_col='Date', parse_dates=True)
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 147278 entries, 2019-11-01 00:00:00 to 2021-12-31 23:00:00
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Fremont Bridge Total          147256 non-null  float64
#  1   Fremont Bridge East Sidewalk  147256 non-null  float64
#  2   Fremont Bridge West Sidewalk  147255 non-null  float64
# dtypes: float64(3)
# memory usage: 4.5 MB

# %%
data.index
# Out:
# DatetimeIndex(['2019-11-01 00:00:00', '2019-11-01 01:00:00',
#                '2019-11-01 02:00:00', '2019-11-01 03:00:00',
#                '2019-11-01 04:00:00', '2019-11-01 05:00:00',
#                '2019-11-01 06:00:00', '2019-11-01 07:00:00',
#                '2019-11-01 08:00:00', '2019-11-01 09:00:00',
#                ...
#                '2021-12-31 14:00:00', '2021-12-31 15:00:00',
#                '2021-12-31 16:00:00', '2021-12-31 17:00:00',
#                '2021-12-31 18:00:00', '2021-12-31 19:00:00',
#                '2021-12-31 20:00:00', '2021-12-31 21:00:00',
#                '2021-12-31 22:00:00', '2021-12-31 23:00:00'],
#               dtype='datetime64[ns]', name='Date', length=147278, freq=None)

# %%
data = data.dropna()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 147255 entries, 2019-11-01 00:00:00 to 2021-12-31 23:00:00
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Fremont Bridge Total          147255 non-null  float64
#  1   Fremont Bridge East Sidewalk  147255 non-null  float64
#  2   Fremont Bridge West Sidewalk  147255 non-null  float64
# dtypes: float64(3)
# memory usage: 4.5 MB

# %%
data.head()
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2019-11-01 00:00:00                  12.0                           7.0
# 2019-11-01 01:00:00                   7.0                           0.0
# 2019-11-01 02:00:00                   1.0                           0.0
# 2019-11-01 03:00:00                   6.0                           6.0
# 2019-11-01 04:00:00                   6.0                           5.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2019-11-01 00:00:00                           5.0
# 2019-11-01 01:00:00                           7.0
# 2019-11-01 02:00:00                           1.0
# 2019-11-01 03:00:00                           0.0
# 2019-11-01 04:00:00                           1.0

# %% [markdown]
# FremontBridge 데이터 분석 실습 과제
# 과제 1: 데이터 선택 및 조건 필터링
# 1. iloc 사용 - 데이터셋의 첫 15개의 행에서 west와 east 열만 선택하여 출력하세요.

# %%
data1 = data.iloc[:15, 1:]
print(data1.shape)
print(data1)
# Out:
# (15, 2)
#                      Fremont Bridge East Sidewalk  \
# Date
# 2019-11-01 00:00:00                           7.0
# 2019-11-01 01:00:00                           0.0
# 2019-11-01 02:00:00                           0.0
# 2019-11-01 03:00:00                           6.0
# 2019-11-01 04:00:00                           5.0
# 2019-11-01 05:00:00                           9.0
# 2019-11-01 06:00:00                          43.0
# 2019-11-01 07:00:00                         120.0
# 2019-11-01 08:00:00                         261.0
# 2019-11-01 09:00:00                         130.0
# 2019-11-01 10:00:00                          56.0
# 2019-11-01 11:00:00                          46.0
# 2019-11-01 12:00:00                          40.0
# 2019-11-01 13:00:00                          46.0
# 2019-11-01 14:00:00                          46.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2019-11-01 00:00:00                           5.0
# ...

# %% [markdown]
# 2. loc 사용
# west 열과 east 열의 값이 모두 50 이상인 데이터를 선택하고, 해당 데이터의 west와 east 열 각각의 평균을 계산하세요.

# %%
data2 = data.loc[(data['Fremont Bridge East Sidewalk'] >= 50) & (data['Fremont Bridge West Sidewalk'] >= 50)]
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 44767 entries, 2019-11-01 07:00:00 to 2021-12-19 15:00:00
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Fremont Bridge Total          44767 non-null  float64
#  1   Fremont Bridge East Sidewalk  44767 non-null  float64
#  2   Fremont Bridge West Sidewalk  44767 non-null  float64
# dtypes: float64(3)
# memory usage: 1.4 MB

# %%
avg_east = np.average(data2.iloc[1])
# avg_east2 = data2.iloc[1].mean()
avg_west= np.average(data2.iloc[2])
print("Average of Fremont Bridge East Sidewalk(>= 50) : ", avg_east)
# print("Average of Fremont Bridge East Sidewalk(>= 50) : ", avg_east2)
print("Average of Fremont Bridge West Sidewalk(>= 50) : ", avg_west)
# Out:
# Average of Fremont Bridge East Sidewalk(>= 50) :  388.6666666666667
# Average of Fremont Bridge West Sidewalk(>= 50) :  221.33333333333334

# %% [markdown]
# 3. 조건에 따른 데이터 필터링
# west 열의 값이 400 이상이고 east 열의 값이 (west 값의 )0.6 이상인 데이터를 선택하여 출력하세요.
# (그냥 0.6이상은 의미가 없어서 추가함)

# %%
data3 = data[(data.iloc[:, 1] >= 0.6 * data.iloc[:, 2]) & (data.iloc[:, 2] >= 400)]
data3
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2019-11-04 08:00:00                 754.0                         322.0
# 2013-05-01 18:00:00                 666.0                         257.0
# 2014-04-29 18:00:00                 669.0                         261.0
# 2014-05-14 18:00:00                 683.0                         271.0
# 2013-05-01 18:00:00                 666.0                         257.0
# ...                                   ...                           ...
# 2019-10-01 08:00:00                 781.0                         369.0
# 2019-10-02 08:00:00                 700.0                         279.0
# 2019-10-14 08:00:00                 743.0                         314.0
# 2019-10-23 08:00:00                 709.0                         302.0
# 2019-11-04 08:00:00                 754.0                         322.0
#
#                      Fremont Bridge West Sidewalk
# Date
# ...

# %% [markdown]
# 과제 2: 누락 데이터 처리
# 1. 누락 데이터 생성
# DIS라는 새로운 열을 추가하고, 무작위로 15%의 데이터를 NaN 값으로 설정하세요.

# %%
data2 = data.copy()
indices = np.random.choice(data2.index, int(len(data2) * 0.15), replace=False)
dis = [np.random.randint(0, 15) for _ in range(len(data2))]

# %%
data2['DIS'] = dis
data2.loc[indices, 'DIS'] = np.nan
data2.info()
data2.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 147255 entries, 2019-11-01 00:00:00 to 2021-12-31 23:00:00
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Fremont Bridge Total          147255 non-null  float64
#  1   Fremont Bridge East Sidewalk  147255 non-null  float64
#  2   Fremont Bridge West Sidewalk  147255 non-null  float64
#  3   DIS                           108218 non-null  float64
# dtypes: float64(4)
# memory usage: 9.6 MB
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2019-11-01 00:00:00                  12.0                           7.0
# 2019-11-01 01:00:00                   7.0                           0.0
# 2019-11-01 02:00:00                   1.0                           0.0
# 2019-11-01 03:00:00                   6.0                           6.0
# ...

# %% [markdown]
# 2. 누락 데이터 처리
# <br />
# (a) 누락 데이터를 포함하는 행을 삭제한 새로운 데이터를 생성하고, 이를 확인하세요.

# %%
data3 = data2.dropna()
data2.info()
data3.info()
data3.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 147255 entries, 2019-11-01 00:00:00 to 2021-12-31 23:00:00
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Fremont Bridge Total          147255 non-null  float64
#  1   Fremont Bridge East Sidewalk  147255 non-null  float64
#  2   Fremont Bridge West Sidewalk  147255 non-null  float64
#  3   DIS                           108218 non-null  float64
# dtypes: float64(4)
# memory usage: 9.6 MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 108218 entries, 2019-11-01 00:00:00 to 2021-12-31 23:00:00
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Fremont Bridge Total          108218 non-null  float64
#  1   Fremont Bridge East Sidewalk  108218 non-null  float64
# ...

# %% [markdown]
# &emsp;&emsp;(b) 누락 데이터를 DIS 열의 중앙값으로 대체한 새로운 데이터를 생성하고, 이를 확인하세요.

# %%
data2[data2['DIS'].isnull()]
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2019-11-01 02:00:00                   1.0                           0.0
# 2019-11-01 03:00:00                   6.0                           6.0
# 2019-11-01 10:00:00                 124.0                          56.0
# 2019-11-01 11:00:00                  94.0                          46.0
# 2019-11-01 15:00:00                 214.0                          55.0
# ...                                   ...                           ...
# 2021-12-29 22:00:00                   1.0                           0.0
# 2021-12-30 21:00:00                   3.0                           0.0
# 2021-12-31 09:00:00                   3.0                           2.0
# 2021-12-31 14:00:00                   8.0                           7.0
# 2021-12-31 22:00:00                   0.0                           0.0
#
#                      Fremont Bridge West Sidewalk  DIS
# Date
# ...

# %%
mean1 = np.nanmean(data2['DIS'].values)
mean2 = np.mean(data2['DIS'].values)
mean3 = data2.loc[:, 'DIS'].mean()
mean4 = data2['DIS'].mean()
mean5 = data2['DIS'].values.mean()
mean1, mean2, mean3, mean4, mean5
# Out:
# (np.float64(7.0055536047607605),
#  np.float64(nan),
#  np.float64(7.0055536047607605),
#  np.float64(7.0055536047607605),
#  np.float64(nan))

# %%
medi = data2['DIS'].median()
data3 = data2.fillna(medi)
print('median : ', medi)
data3.info()
print(data3.head(10))
# Out:
# median :  7.0
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 147255 entries, 2019-11-01 00:00:00 to 2021-12-31 23:00:00
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Fremont Bridge Total          147255 non-null  float64
#  1   Fremont Bridge East Sidewalk  147255 non-null  float64
#  2   Fremont Bridge West Sidewalk  147255 non-null  float64
#  3   DIS                           147255 non-null  float64
# dtypes: float64(4)
# memory usage: 9.6 MB
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2019-11-01 00:00:00                  12.0                           7.0
# 2019-11-01 01:00:00                   7.0                           0.0
# 2019-11-01 02:00:00                   1.0                           0.0
# 2019-11-01 03:00:00                   6.0                           6.0
# ...

# %% [markdown]
# 과제 3: 기상 데이터와 자전거 사용자 수 관계 분석
#
# 배경
# 기상 데이터(Temperature, Rainfall, 등)가 주어졌다고 가정하고, 이를 Fremont Bridge 데이터와 결합합니다.
#
# 실습 문제
# 1) 임의의 기상 데이터를 생성하여 Temperature와 Rainfall 열을 추가하세요.
# Temperature는 40~80°F 사이의 임의의 정수로 구성됩니다.
# Rainfall은 0~5mm 사이의 임의의 실수로 구성됩니다.

# %%
merged = data.copy()
temperature = np.random.randint(40, 81, len(merged))
rainfall = np.random.rand(len(merged)) * 5
merged['Temperature'] = temperature
merged['Rainfall'] = rainfall

# %%
merged.info()
print(merged.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 147278 entries, 2019-11-01 00:00:00 to 2021-12-31 23:00:00
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Fremont Bridge Total          147256 non-null  float64
#  1   Fremont Bridge East Sidewalk  147256 non-null  float64
#  2   Fremont Bridge West Sidewalk  147255 non-null  float64
#  3   Temperature                   147278 non-null  int32
#  4   Rainfall                      147278 non-null  float64
# dtypes: float64(4), int32(1)
# memory usage: 10.2 MB
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2019-11-01 00:00:00                  12.0                           7.0
# 2019-11-01 01:00:00                   7.0                           0.0
# 2019-11-01 02:00:00                   1.0                           0.0
# ...

# %% [markdown]
# 2) Temperature와 Rainfall이 west와 east 통행량에 미치는 영향을 분석하기 위해, 조건에 따른 데이터를 필터링하세요.
# Temperature가 60°F 이상일 때의 통행량 평균.
# Rainfall이 2mm 이하일 때의 통행량 평균.

# %%
avg_by_temp = merged['Fremont Bridge Total'][merged.iloc[:, 3] >= 60].mean()
avg_by_rain = merged['Fremont Bridge Total'][merged.iloc[:, 4] <= 2].mean()
print(avg_by_temp, avg_by_rain)
# Out:
# 109.52868373525975 109.9856900356476

# %% [markdown]
# 3) 위 데이터를 시각화하여 분석 결과를 그래프로 표현하세요.
# Temperature와 west 통행량의 관계를 나타내는 산점도.
# Rainfall과 east 통행량의 관계를 나타내는 선 그래프.

# %%
merged.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# p.219

# %%
data.resample('D').sum()
# Out:
#             Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03                7042.0                        3520.0
# 2012-10-04                6950.0                        3416.0
# 2012-10-05                6296.0                        3116.0
# 2012-10-06                4012.0                        2160.0
# 2012-10-07                4284.0                        2382.0
# ...                          ...                           ...
# 2021-12-27                  74.0                          23.0
# 2021-12-28                  91.0                          32.0
# 2021-12-29                  75.0                          32.0
# 2021-12-30                  77.0                          37.0
# 2021-12-31                  52.0                          31.0
#
#             Fremont Bridge West Sidewalk
# Date
# 2012-10-03                        3522.0
# 2012-10-04                        3534.0
# 2012-10-05                        3180.0
# ...

# %%
import matplotlib.pyplot as plt

x1 = merged.iloc[:, 3].values # temperature
y1 = merged.iloc[:, 2] # west

plt.figure(figsize=(6, 6))
plt.scatter(x1, y1, marker='.')
plt.xlabel('Temperature')
plt.ylabel('Fremont Bridge West Sidewalk')
# Out:
# Text(0, 0.5, 'Fremont Bridge West Sidewalk')

# %%
selected = merged.sample(300)
sorted_data = selected.sort_values(by='Rainfall')
x2 = sorted_data.iloc[:, 4] # rainfall
y2 = sorted_data.iloc[:, 1] # east
print(x2)

plt.figure(figsize=(12, 6))
plt.plot(x2, y2, '-')
# Out:
# Date
# 2017-10-25 09:00:00    0.015674
# 2014-12-21 18:00:00    0.078474
# 2016-02-02 15:00:00    0.079348
# 2017-12-28 22:00:00    0.080544
# 2013-06-13 21:00:00    0.081173
#                          ...
# 2019-01-26 04:00:00    4.915173
# 2018-03-09 11:00:00    4.936399
# 2016-06-21 04:00:00    4.955724
# 2018-03-19 06:00:00    4.971596
# 2014-08-27 07:00:00    4.976177
# Name: Rainfall, Length: 300, dtype: float64

# %%
x3 = merged.iloc[:, 3].values # temperature
x3 = np.unique(x3)[:-1] # 결측치 80 제거
# print(x3)

west_by_temp = merged.groupby('Temperature')['Fremont Bridge East Sidewalk'].mean() # west
west_by_temp = west_by_temp[:-1] # 결측치 80 제거
# print(west_by_temp)
plt.figure(figsize=(12, 6))
plt.plot(x3, west_by_temp)
